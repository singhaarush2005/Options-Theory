# %%
import pandas as pd
import numpy as np

# %%
import yfinance as yf
df = yf.download('META', start='2017-12-31', end='2018-12-30')
df.reset_index(inplace=True)
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
df
# Out:
# Price        Date   Adj Close       Close        High         Low        Open  \
# Ticker                   META        META        META        META        META
# 0      2018-01-02  180.729630  181.419998  181.580002  177.550003  177.679993
# 1      2018-01-03  183.967255  184.669998  184.779999  181.330002  181.880005
# 2      2018-01-04  183.628540  184.330002  186.210007  184.100006  184.899994
# 3      2018-01-05  186.138962  186.850006  186.899994  184.929993  185.589996
# 4      2018-01-08  187.563522  188.279999  188.899994  186.330002  187.199997
# ..            ...         ...         ...         ...         ...         ...
# 245    2018-12-21  124.474510  124.949997  134.899994  123.419998  133.389999
# 246    2018-12-24  123.587898  124.059998  129.740005  123.019997  123.099998
# 247    2018-12-26  133.669388  134.179993  134.240005  125.889999  126.000000
# 248    2018-12-27  134.008118  134.520004  134.990005  129.669998  132.440002
# ...

# %%
cols_drop = ['Adj Close','High','Low','Volume']
df.drop(columns=cols_drop, inplace=True)
df
# Out:
# <ipython-input-69-84bd822aac1d>:2: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   df.drop(columns=cols_drop, inplace=True)
# Price        Date       Close        Open
# Ticker                   META        META
# 0      2018-01-02  181.419998  177.679993
# 1      2018-01-03  184.669998  181.880005
# 2      2018-01-04  184.330002  184.899994
# 3      2018-01-05  186.850006  185.589996
# 4      2018-01-08  188.279999  187.199997
# ..            ...         ...         ...
# 245    2018-12-21  124.949997  133.389999
# 246    2018-12-24  124.059998  123.099998
# 247    2018-12-26  134.179993  126.000000
# 248    2018-12-27  134.520004  132.440002
# 249    2018-12-28  133.199997  135.339996
#
# [250 rows x 3 columns]

# %%
df['Daily_Log_Return'] = np.log(df.Close/df.Open)

# %%
df
# Out:
# Price        Date       Close        Open Daily_Log_Return
# Ticker                   META        META
# 0      2018-01-02  181.419998  177.679993         0.020831
# 1      2018-01-03  184.669998  181.880005         0.015223
# 2      2018-01-04  184.330002  184.899994        -0.003087
# 3      2018-01-05  186.850006  185.589996         0.006766
# 4      2018-01-08  188.279999  187.199997         0.005753
# ..            ...         ...         ...              ...
# 245    2018-12-21  124.949997  133.389999        -0.065364
# 246    2018-12-24  124.059998  123.099998         0.007768
# 247    2018-12-26  134.179993  126.000000         0.062900
# 248    2018-12-27  134.520004  132.440002         0.015583
# 249    2018-12-28  133.199997  135.339996        -0.015938
#
# [250 rows x 4 columns]

# %%
df.isna().sum()
# Out:
# Price             Ticker
# Date                        0
# Close             META      0
# Open              META      0
# Daily_Log_Return            0
# dtype: int64

# %%
daily_volatility = df.Daily_Log_Return.std()
daily_volatility
# Out:
# 0.01778659322179065

# %%
annual_vol = std*np.sqrt(252)
annual_vol
# Out:
# 0.2823534140155511

# %%
def annual_vol(df):
    """
    Function to calculate annual volatility

    Parameters
    ----------
    df : dataframe
         Stock info

    Returns
    -------
    vol : float
        annual volatility of the stock
    """

    log_return = np.log(df.Close/df.Open)
    log_return = log_return.dropna()
    daily_vol = log_return.std()
    vol = daily_vol*np.sqrt(252)


    return vol

# %%
vol = annual_vol(df).iloc[0]
print(vol)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-48fc44650f14> in <cell line: 1>()
# ----> 1 vol = annual_vol(df).iloc[0]
#       2 print(vol)
#
# NameError: name 'annual_vol' is not defined
